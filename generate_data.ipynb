# %%
import numpy as np
from src.algos.chebae import chebae
from src.algos.glsae import glsae, gmmae
from src.algos.gdmae import gdmae
from src.algos.sensing import compressed_sensing
from src.algos.csae import csae
from src.algos.qpe import qpe
from src.algos.esprit import esprit_cosine
from src.algos.power_law import power_law
from src.util.csae_util import CSAECache
import json

rng = np.random.default_rng()
target = 1/np.pi

# %%
csae_cache = [CSAECache(i) for i in np.arange(1, 9)]

# %%
with open('./data/heisenberg/qpe.jsonl', 'w') as f:
    for j in range(100):
        res = [qpe(target, i, 20, rng) for i in 2 ** np.arange(1, 16)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/chebae.jsonl', 'w') as f:
    for j in range(100):
        res = [chebae(target, 0.5 / i, 0.05, rng) for i in 2 ** np.arange(1, 16)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/csae.jsonl', 'w') as f:
    for j in range(100):
        res = [csae(target, i, rng, 4, cache=csae_cache[i-1]) for i in np.arange(1, 8)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/sensing.jsonl', 'w') as f:
    for j in range(100):
        res = [compressed_sensing(target, i, i * np.max((2 * np.log2(i), 20)).astype(int), rng) for i in 2 ** np.arange(1, 16)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/glsae.jsonl', 'w') as f:
    for j in range(100):
        res = [glsae(target, i, i * 20, rng) for i in 2 ** np.arange(0, 16)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/gmmae.jsonl', 'w') as f:
    for j in range(100):
        res = [gmmae(target, i, i * 20, rng) for i in 2 ** np.arange(0, 16)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/heisenberg/gdmae.jsonl', 'w') as f:
    for j in range(100):
        res = [gdmae(target, i, i * 10, rng) for i in 2 ** np.arange(0, 16)]
        y, x, z = zip(*res)
        json.dump({"query": (np.array(x)*2).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/uniform/esprit.jsonl', 'w') as f:
    for j in range(100):
        res = [esprit_cosine(target, i, 16, rng) for i in 2 ** np.arange(1, 12)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/uniform/powerlaw.jsonl', 'w') as f:
    for j in range(100):
        res = [power_law(target, 0.5/i, 1/3.0, rng, n_shots=16) for i in 2 ** np.arange(0, 15)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/uniform/glsae.jsonl', 'w') as f:
    for j in range(100):
        res = [glsae(target, i, i**2*4, rng, G=np.ceil(i**0.5)*8) for i in 2 ** np.arange(1, 12)]
        y, x, z = zip(*res)
        json.dump({"query": np.array(x).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

# %%
with open('./data/uniform/gdmae.jsonl', 'w') as f:
    for j in range(100):
        res = [gdmae(target, i, i**2*2, rng, G=np.ceil(i**0.5)*8) for i in 2 ** np.arange(1, 12)]
        y, x, z = zip(*res)
        json.dump({"query": (2*np.array(x)).tolist(),"value": np.array(y).tolist(), "depth": np.array(z).tolist()}, f)
        f.write("\n")

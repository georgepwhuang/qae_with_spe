# %%
import numpy as np
from matplotlib import pyplot as plt
import json

target = 1/np.pi

# %%
plt.rcParams.update({'font.size': 18, 'font.family': "serif","font.serif": "CMU Serif", 'text.usetex': True})

# %%
algos = ["QPE", "Sensing", "GLSAE", "GMMAE"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     ('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
fig, ax = plt.subplots(1, 2, figsize=(20,5))
for algo, (_,style) in zip(algos,linestyle_tuple):
    with open(f'./output/heisenberg/{algo.lower()}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[0].plot(query,error,label=algo,linestyle=style,linewidth=2)
    ax[1].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel("Queries")
ax[0].set_ylabel("Error")
ax[0].legend(loc="lower left")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel("Depth")
ax[1].set_ylabel("Error")
ax[1].legend(loc="lower left")
plt.tight_layout()
plt.savefig("others.pdf", bbox_inches='tight')

# %%
algos = ["QPE", "ChebAE", "CSAE", "GLSAE", "GDMAE"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     ('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
fig, ax = plt.subplots(1, 2, figsize=(20,5))
for algo, (_,style) in zip(algos,linestyle_tuple):
    with open(f'./output/heisenberg/{algo.lower()}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[0].plot(query,error,label=algo,linestyle=style,linewidth=2)
    ax[1].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel("Queries")
ax[0].set_ylabel("Error")
ax[0].legend(loc="lower left")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel("Depth")
ax[1].set_ylabel("Error")
ax[1].legend(loc="lower left")
plt.tight_layout()
plt.savefig("heisenberg.pdf", bbox_inches='tight')

# %%
algos = ["PowerLaw", "ESPRIT", "GDMAE", "GLSAE"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     ('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
fig, ax = plt.subplots(1, 2, figsize=(20,5))
for algo, (_,style) in zip(algos,linestyle_tuple):
    with open(f'./output/uniform/{algo.lower()}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[0].plot(query,error,label=algo,linestyle=style,linewidth=2)
    ax[1].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel("Queries")
ax[0].set_ylabel("Error")
ax[0].legend(loc="lower left")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel("Depth")
ax[1].set_ylabel("Error")
ax[1].legend(loc="lower left")
plt.tight_layout()
plt.savefig("uniform.pdf", bbox_inches='tight')

# %%
algos = ["CSAE (HL)", "GLSAE (HL)", "Power Law (LD)", "GLSAE (LD)"]
locs = ["heisenberg/csae", "heisenberg/glsae", "uniform/powerlaw", "uniform/glsae"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     #('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
fig, ax = plt.subplots(1, 2, figsize=(20,5))
for algo, (_,style), loc in zip(algos,linestyle_tuple,locs):
    with open(f'./output/{loc}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[0].plot(query,error,label=algo,linestyle=style,linewidth=2)
    ax[1].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel("Queries")
ax[0].set_ylabel("Error")
ax[0].legend(loc="lower left")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel("Depth")
ax[1].set_ylabel("Error")
ax[1].legend(loc="lower left")
plt.tight_layout()
plt.savefig("compare.pdf", bbox_inches='tight')

# %%
algos = ["QPE", "ChebAE", "CSAE", "GLSAE", "GDMAE"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     ('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
fig, ax = plt.subplots(1, 2, figsize=(20,5))
for algo, (_,style) in zip(algos,linestyle_tuple):
    with open(f'./output/heisenberg/{algo.lower()}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[0].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[0].set_xscale('log')
ax[0].set_yscale('log')
ax[0].set_xlabel("Depth")
ax[0].set_ylabel("Error")
ax[0].legend(loc="lower left")

algos = ["CSAE (HL)", "GLSAE (HL)", "Power Law (LD)", "GLSAE (LD)"]
locs = ["heisenberg/csae", "heisenberg/glsae", "uniform/powerlaw", "uniform/glsae"]
linestyle_tuple = [
     ('dotted',                (0, (1, 2))),
     ('densely dotted',        (0, (1, 1))),
     ('dashed',                (0, (5, 3))),
     ('densely dashed',        (0, (3, 1))),
     #('dashdotted',            (0, (3, 2, 1, 2))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),
     ('solid', 'solid')]
for algo, (_,style), loc in zip(algos,linestyle_tuple,locs):
    with open(f'./output/{loc}.jsonl', 'r') as json_file:
        json_list = list(json_file)
    query = []
    depth = []
    value = []
    for json_str in json_list:
        res = json.loads(json_str)
        query.append(res["query"])
        depth.append(res["depth"])
        value.append(res["value"])
    query = np.max(query,axis=0)
    depth = np.max(depth,axis=0)
    error = np.median(np.abs(np.array(value)-target), axis=0)
    ax[1].plot(depth,error,label=algo,linestyle=style,linewidth=2)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlabel("Depth")
ax[1].set_ylabel("Error")
ax[1].legend(loc="lower left")
plt.tight_layout()
plt.savefig("numerics.pdf", bbox_inches='tight')
